# %%
from SMBHB_pop_synth import inverse_comoving_to_redshift_numba

# %%
import numpy as np
dmov = np.linspace(1, 10000, 10000)
import matplotlib.pyplot as plt
plt.plot(inverse_comoving_to_redshift_numba(dmov), dmov)
plt.ylabel(r"$D_{\rm{comov}} [Mpc]")
plt.xlabel(r"$z$")
plt.xlim(0, 1)
plt.ylim(0, 5000)
# Out:
# (0.0, 5000.0)

# %%
print(inverse_comoving_to_redshift_numba([1200]))
# Out:
# [0.30564528]
